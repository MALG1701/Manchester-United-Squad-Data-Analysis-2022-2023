# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_excel(r'C:\Users\mlopez\Downloads\MUFC 2022_2023.xlsx')

# %%
data.head()
# Out:
#         Date           Time            Comp        Round  Day Venue Result  \
# 0 2022-08-07  14:00 (09:00)  Premier League  Matchweek 1  Sun  Home      L
# 1 2022-08-13  17:30 (12:30)  Premier League  Matchweek 2  Sat  Away      L
# 2 2022-08-22  20:00 (15:00)  Premier League  Matchweek 3  Mon  Home      W
# 3 2022-08-27  12:30 (07:30)  Premier League  Matchweek 4  Sat  Away      W
# 4 2022-09-01  20:00 (15:00)  Premier League  Matchweek 5  Thu  Away      W
#
#    GF  GA        Opponent  ...   xG  Poss  Attendance          Captain  \
# 0   1   2        Brighton  ...  1.4    62     73711.0    Harry Maguire
# 1   0   4       Brentford  ...  0.9    66     17051.0    Harry Maguire
# 2   2   1       Liverpool  ...  1.8    30     74147.0  Bruno Fernandes
# 3   1   0     Southampton  ...  1.1    51     31196.0  Bruno Fernandes
# 4   1   0  Leicester City  ...  1.5    47     32226.0  Bruno Fernandes
#
#              Formation         Referee  Match Report   Avg Poss    Avg xG  \
# ...

# %%
avg_xg=data['xG'].mean()
sum_xg=data['xG'].sum()
print(avg_xg,sum_xg)
# Out:
# 1.594444444444444 28.699999999999996

# %%
avg_xga=data['xGA'].mean()
sum_xga=data['xGA'].sum()
print(avg_xga,sum_xga)
# Out:
# 1.0555555555555558 19.000000000000004

# %%
max_xg=data['xG'].max()
min_xg=data['xG'].min()
print(max_xg,min_xg)
# Out:
# 4.2 0.7

# %%
x=data['Opponent']
y=data['xG']
data['Avg xG']=data['xG'].mean()

plt.figure(figsize=(15,5))
plt.xticks(rotation=45)
plt.title('xG Manchester United temporada 2022-2023')
plt.xlabel('Oponentes')
plt.ylabel('xG')
plt.scatter(x,y)
plt.plot(x,data['Avg xG'], label='xG Promedio')

# %%
avg_poss=data['Poss'].mean()
avg_poss
# Out:
# 56.888888888888886

# %%
sum_gf=data['GF'].sum()
sum_ga=data['GA'].sum()
avg_gf=data['GF'].mean()
avg_ga=data['GA'].mean()
print(sum_gf,sum_ga,avg_gf,avg_ga)
# Out:
# 27 19 1.5 1.0555555555555556

# %%
team_max_xg=data.groupby(by = 'Opponent').max()['xG']
team_max_xg=team_max_xg.sort_values(ascending=False)

print(team_max_xg.index[0],team_max_xg.max())
# Out:
# AC Omonia 4.2

# %%
team_min_xg=data.groupby(by = 'Opponent').min()['xG']
team_min_xg=team_min_xg.sort_values(ascending=True)

print(team_min_xg.index[0],team_min_xg.min())
# Out:
# Real Sociedad 0.7

# %%
team_max_xga=data.groupby(by = 'Opponent').max()['xGA']
team_max_xga=team_max_xga.sort_values(ascending=False)

print(team_max_xga.index[0],team_max_xga.max())
# Out:
# Manchester City 3.2

# %%
team_min_xga=data.groupby(by = 'Opponent').min()['xGA']
team_min_xga=team_min_xga.sort_values(ascending=True)

print(team_min_xga.index[0],team_min_xga.min())
# Out:
# Sheriff Tiraspol 0.0

# %%
x=data['Opponent']
y=data['Poss']

plt.figure(figsize=(12,5))
plt.xticks(rotation=45)
plt.title('xG Manchester United temporada 2022-2023')
plt.xlabel('Oponentes')
plt.ylabel('Posesion')
plt.scatter(x,y,label='test')
plt.plot(x,data['Avg Poss'], label='Posesion Promedio')

# %%
data['Avg Poss']=data['Poss'].mean()
data.head()
# Out:
#         Date           Time            Comp        Round  Day Venue Result  \
# 0 2022-08-07  14:00 (09:00)  Premier League  Matchweek 1  Sun  Home      L
# 1 2022-08-13  17:30 (12:30)  Premier League  Matchweek 2  Sat  Away      L
# 2 2022-08-22  20:00 (15:00)  Premier League  Matchweek 3  Mon  Home      W
# 3 2022-08-27  12:30 (07:30)  Premier League  Matchweek 4  Sat  Away      W
# 4 2022-09-01  20:00 (15:00)  Premier League  Matchweek 5  Thu  Away      W
#
#    GF  GA        Opponent  ...   xG  Poss  Attendance          Captain  \
# 0   1   2        Brighton  ...  1.4    62     73711.0    Harry Maguire
# 1   0   4       Brentford  ...  0.9    66     17051.0    Harry Maguire
# 2   2   1       Liverpool  ...  1.8    30     74147.0  Bruno Fernandes
# 3   1   0     Southampton  ...  1.1    51     31196.0  Bruno Fernandes
# 4   1   0  Leicester City  ...  1.5    47     32226.0  Bruno Fernandes
#
#              Formation         Referee  Match Report Notes   Avg Poss  \
# ...

# %%
data=data.drop('Notes',axis='columns')
data.head()
# Out:
#         Date           Time            Comp        Round  Day Venue Result  \
# 0 2022-08-07  14:00 (09:00)  Premier League  Matchweek 1  Sun  Home      L
# 1 2022-08-13  17:30 (12:30)  Premier League  Matchweek 2  Sat  Away      L
# 2 2022-08-22  20:00 (15:00)  Premier League  Matchweek 3  Mon  Home      W
# 3 2022-08-27  12:30 (07:30)  Premier League  Matchweek 4  Sat  Away      W
# 4 2022-09-01  20:00 (15:00)  Premier League  Matchweek 5  Thu  Away      W
#
#    GF  GA        Opponent  xGA   xG  Poss  Attendance          Captain  \
# 0   1   2        Brighton  1.5  1.4    62     73711.0    Harry Maguire
# 1   0   4       Brentford  1.6  0.9    66     17051.0    Harry Maguire
# 2   2   1       Liverpool  1.3  1.8    30     74147.0  Bruno Fernandes
# 3   1   0     Southampton  1.4  1.1    51     31196.0  Bruno Fernandes
# 4   1   0  Leicester City  0.7  1.5    47     32226.0  Bruno Fernandes
#
#              Formation         Referee  Match Report   Avg Poss    Avg xG
# ...

# %%
data['diff xG']=data['GF']-data['xG']
data.head()
# Out:
#         Date           Time            Comp        Round  Day Venue Result  \
# 0 2022-08-07  14:00 (09:00)  Premier League  Matchweek 1  Sun  Home      L
# 1 2022-08-13  17:30 (12:30)  Premier League  Matchweek 2  Sat  Away      L
# 2 2022-08-22  20:00 (15:00)  Premier League  Matchweek 3  Mon  Home      W
# 3 2022-08-27  12:30 (07:30)  Premier League  Matchweek 4  Sat  Away      W
# 4 2022-09-01  20:00 (15:00)  Premier League  Matchweek 5  Thu  Away      W
#
#    GF  GA        Opponent  ...   xG  Poss  Attendance          Captain  \
# 0   1   2        Brighton  ...  1.4    62     73711.0    Harry Maguire
# 1   0   4       Brentford  ...  0.9    66     17051.0    Harry Maguire
# 2   2   1       Liverpool  ...  1.8    30     74147.0  Bruno Fernandes
# 3   1   0     Southampton  ...  1.1    51     31196.0  Bruno Fernandes
# 4   1   0  Leicester City  ...  1.5    47     32226.0  Bruno Fernandes
#
#              Formation         Referee  Match Report   Avg Poss    Avg xG  \
# ...

# %%
data_pl=data[data['Comp']=='Premier League']
data_pl_xg=data_pl['xG'].sum()
data_pl_avgxg=data_pl['xG'].mean()
data_pl_w=data_pl[data_pl['Result']=='W']
data_pl_w=data_pl_w['Result'].count()

print(data_pl_xg,data_pl_avgxg,data_pl_w)
# Out:
# 15.600000000000001 1.3 7

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 16
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          12 non-null     datetime64[ns]
#  1   Time          12 non-null     object
#  2   Comp          12 non-null     object
#  3   Round         12 non-null     object
#  4   Day           12 non-null     object
#  5   Venue         12 non-null     object
#  6   Result        12 non-null     object
#  7   GF            12 non-null     int64
#  8   GA            12 non-null     int64
#  9   Opponent      12 non-null     object
#  10  xGA           12 non-null     float64
#  11  xG            12 non-null     float64
#  12  Poss          12 non-null     int64
#  13  Attendance    12 non-null     float64
#  14  Captain       12 non-null     object
#  15  Formation     12 non-null     object
#  16  Referee       12 non-null     object
#  17  Match Report  12 non-null     object
# ...

# %%
data_squad=pd.read_excel(r'C:\Users\mlopez\Documents\united squad 2223.xlsx')
data_squad.head()
# Out:
#       Player  Player LN   Nation    Pos     Age  MP  Starts   Min   90s  Gls  \
# 0      Bruno  Fernandes   pt POR     MF  28-058  18      17  1544  17.2    2
# 1      Diogo      Dalot   pt POR     DF  23-232  18      18  1520  16.9    1
# 2   Lisandro   Martínez   ar ARG     DF  24-291  18      17  1473  16.4    0
# 3  Christian    Eriksen   dk DEN     MF  30-264  17      15  1281  14.2    0
# 4     Marcus   Rashford  eng ENG  FW,MF  25-005  16      12  1159  12.9    7
#
#    ...  xAG  npxG+xAG  xG+xAG  SCA90  GCA90  Gls 90  Shots  SoT/90  Pass 1/3  \
# 0  ...  4.8       8.1     8.1   5.19   0.41    0.17   2.00    0.75        61
# 1  ...  2.4       3.2     3.3   2.84   0.18    0.00   0.84    0.25        26
# 2  ...  0.3       0.4     0.5   0.98   0.06    0.00   0.26    0.00        17
# 3  ...  2.7       4.3     4.4   4.22   0.49    0.00   1.77    0.73        35
# 4  ...  2.3       9.1     9.1   3.03   0.23    0.38   2.86    1.05        22
#
#    Prog
# 0    36
# 1    43
# 2    36
# ...

# %%
a=data_squad['xG']
b=data_squad['xAG']
#data_squad['Avg xG+xAG']=data_squad['xG+xAG'].mean()
c=data_squad['Player LN']
c_t=c.transpose()


plt.figure(figsize=(15,5))
plt.xticks(rotation=0)
plt.title('xG-xAG Manchester United temporada 2022-2023')
plt.xlabel('Goles Esperados (xG)')
plt.ylabel('Asistencias Esperadas (xAG)')
plt.scatter(a,b,label='test')
for i, txt in enumerate(c):
    plt.annotate(txt, (a[i], b[i]))
#plt.plot(a,data_squad['Avg xG+xAG'], label='Posesion Promedio')

# %%
c.head()
# Out:
# 0         David de Gea
# 1      Bruno Fernandes
# 2          Diogo Dalot
# 3    Lisandro Martínez
# 4    Christian Eriksen
# Name: Player, dtype: object

# %%
d=data_squad['GCA90']
e=data_squad['SCA90']
#data_squad['Avg xG+xAG']=data_squad['xG+xAG'].mean()
c=data_squad['Player LN']
c_t=c.transpose()


plt.figure(figsize=(15,5))
plt.xticks(rotation=0)
plt.title('Manchester United 2022-2023: Acciones que generaron Gol/Remate')
plt.xlabel('Acciones que Generaron Gol per 90 min (AGG)')
plt.ylabel('Acciones que Generaron Remate per 90 min (AGR)')
plt.scatter(d,e,label='test')
for i, txt in enumerate(c):
    plt.annotate(txt, (d[i], e[i]))
#plt.plot(a,data_squad['Avg xG+xAG'], label='Posesion Promedio')

# %%
f=data_squad['Prog']
g=data_squad['Pass 1/3']
#data_squad['Avg xG+xAG']=data_squad['xG+xAG'].mean()
c=data_squad['Player LN']
c_t=c.transpose()


plt.figure(figsize=(15,5))
plt.xticks(rotation=0)
plt.title('Manchester United 2022-2023: Pases Progresivos vs. Pases último tercio del campo')
plt.xlabel('Pases Progresivos')
plt.ylabel('Pases al último tercio del campo')
plt.scatter(f,g,label='test')
for i, txt in enumerate(c):
    plt.annotate(txt, (f[i], g[i]))
#plt.plot(a,data_squad['Avg xG+xAG'], label='Posesion Promedio')
